# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_population = pd.read_csv('../../data/population_USA.csv')
df_population
# Out:
#     SUMLEV REGION DIVISION  STATE              NAME  ESTIMATESBASE2020  \
# 0       10      0        0      0     United States          331464948
# 1       20      1        0      0  Northeast Region           57614141
# 2       30      1        1      0       New England           15119994
# 3       30      1        2      0   Middle Atlantic           42494147
# 4       20      2        0      0    Midwest Region           68987296
# ..     ...    ...      ...    ...               ...                ...
# 61      40      4        9     53        Washington            7705267
# 62      40      3        5     54     West Virginia            1793713
# 63      40      2        3     55         Wisconsin            5893713
# 64      40      4        8     56           Wyoming             576850
# 65      40      X        X     72       Puerto Rico            3285874
#
#     POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  POPESTIMATE2023  ...  \
# ...

# %%
df_unemployed = pd.read_excel('../../data/unemployed_reates_USA.xlsx')
df_unemployed
# Out:
#          Unemployment Rates for States Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0              Annual Average Rankings        NaN        NaN         NaN
# 1                          2012 - 2023        NaN        NaN         NaN
# 2                                  NaN        NaN        NaN         NaN
# 3                                  NaN        NaN        NaN         NaN
# 4                                  NaN       2023        NaN         NaN
# 5                                State  Rate_2023       Rank         NaN
# 6                        United States        3.6        ---         NaN
# 7                              Alabama        2.5          7         NaN
# 8                               Alaska        4.2         44         NaN
# 9                              Arizona        3.9         38         NaN
# 10                            Arkansas        3.3         27         NaN
# 11                          California        4.8         49         NaN
# ...

# %%
df_population.isnull().sum()                #No of null values
# Out:
# SUMLEV                   0
# REGION                   0
# DIVISION                 0
# STATE                    0
# NAME                     0
# ESTIMATESBASE2020        0
# POPESTIMATE2020          0
# POPESTIMATE2021          0
# POPESTIMATE2022          0
# POPESTIMATE2023          0
# NPOPCHG_2020             0
# NPOPCHG_2021             0
# NPOPCHG_2022             0
# NPOPCHG_2023             0
# BIRTHS2020               0
# BIRTHS2021               0
# BIRTHS2022               0
# BIRTHS2023               0
# DEATHS2020               0
# DEATHS2021               0
# DEATHS2022               0
# DEATHS2023               0
# NATURALCHG2020           0
# NATURALCHG2021           0
# NATURALCHG2022           0
# NATURALCHG2023           0
# INTERNATIONALMIG2020     0
# INTERNATIONALMIG2021     0
# INTERNATIONALMIG2022     0
# INTERNATIONALMIG2023     0
# DOMESTICMIG2020          0
# DOMESTICMIG2021          0
# DOMESTICMIG2022          0
# DOMESTICMIG2023          0
# ...

# %%
df_unemployed.isnull().sum()                                        #No of null values
# Out:
# Unemployment Rates for States     4
# Unnamed: 1                        6
# Unnamed: 2                        7
# Unnamed: 3                       60
# Unnamed: 4                        6
#                                  ..
# Unnamed: 67                       6
# Unnamed: 68                       7
# Unnamed: 69                      60
# Unnamed: 70                       6
# Unnamed: 71                       6
# Length: 72, dtype: int64

# %%
df_unemployed.drop([0,1,2,3,4],inplace = True)        #drop rows
df_unemployed
# Out:
#          Unemployment Rates for States Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 5                                State  Rate_2023       Rank         NaN
# 6                        United States        3.6        ---         NaN
# 7                              Alabama        2.5          7         NaN
# 8                               Alaska        4.2         44         NaN
# 9                              Arizona        3.9         38         NaN
# 10                            Arkansas        3.3         27         NaN
# 11                          California        4.8         49         NaN
# 12                            Colorado        3.2         23         NaN
# 13                         Connecticut        3.8         36         NaN
# 14                            Delaware          4         42         NaN
# 15                District of Columbia        4.9         50         NaN
# 16                             Florida        2.9         11         NaN
# ...

# %%
df_unemployed.reset_index(drop=True,inplace = True)         # reset the index
df_unemployed
# Out:
#          Unemployment Rates for States Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                                State  Rate_2023       Rank         NaN
# 1                        United States        3.6        ---         NaN
# 2                              Alabama        2.5          7         NaN
# 3                               Alaska        4.2         44         NaN
# 4                              Arizona        3.9         38         NaN
# 5                             Arkansas        3.3         27         NaN
# 6                           California        4.8         49         NaN
# 7                             Colorado        3.2         23         NaN
# 8                          Connecticut        3.8         36         NaN
# 9                             Delaware          4         42         NaN
# 10                District of Columbia        4.9         50         NaN
# 11                             Florida        2.9         11         NaN
# ...

# %%
df_unemployed = df_unemployed.dropna(axis = 1,how = 'all')                     # drop all columns with missing values
df_unemployed
# Out:
#          Unemployment Rates for States Unnamed: 1 Unnamed: 2 Unnamed: 4  \
# 0                                State  Rate_2023       Rank  Rate_2022
# 1                        United States        3.6        ---        3.6
# 2                              Alabama        2.5          7        2.5
# 3                               Alaska        4.2         44        4.2
# 4                              Arizona        3.9         38        3.8
# 5                             Arkansas        3.3         27        3.2
# 6                           California        4.8         49        4.3
# 7                             Colorado        3.2         23        3.1
# 8                          Connecticut        3.8         36        4.1
# 9                             Delaware          4         42        4.3
# 10                District of Columbia        4.9         50        4.7
# 11                             Florida        2.9         11          3
# ...

# %%
df_unemployed = df_unemployed.dropna(axis = 0,how = 'all')                         # drop all rows with missing values
df_unemployed
# Out:
#          Unemployment Rates for States Unnamed: 1 Unnamed: 2 Unnamed: 4  \
# 0                                State  Rate_2023       Rank  Rate_2022
# 1                        United States        3.6        ---        3.6
# 2                              Alabama        2.5          7        2.5
# 3                               Alaska        4.2         44        4.2
# 4                              Arizona        3.9         38        3.8
# 5                             Arkansas        3.3         27        3.2
# 6                           California        4.8         49        4.3
# 7                             Colorado        3.2         23        3.1
# 8                          Connecticut        3.8         36        4.1
# 9                             Delaware          4         42        4.3
# 10                District of Columbia        4.9         50        4.7
# 11                             Florida        2.9         11          3
# ...

# %%
df_unemployed.columns = df_unemployed.iloc[0]                               # set the row value as their column name
df_unemployed = df_unemployed[1:].reset_index(drop = True)
df_unemployed
# Out:
# 0                                State Rate_2023 Rank Rate_2022 Rank  \
# 0                        United States       3.6  ---       3.6  ---
# 1                              Alabama       2.5    7       2.5    7
# 2                               Alaska       4.2   44       4.2   45
# 3                              Arizona       3.9   38       3.8   32
# 4                             Arkansas       3.3   27       3.2   23
# 5                           California       4.8   49       4.3   46
# 6                             Colorado       3.2   23       3.1   19
# 7                          Connecticut       3.8   36       4.1   40
# 8                             Delaware         4   42       4.3   46
# 9                 District of Columbia       4.9   50       4.7   50
# 10                             Florida       2.9   11         3   17
# 11                             Georgia       3.2   23       3.1   19
# 12                              Hawaii         3   17       3.3   26
# ...

# %%
df_unemployed.columns.value_counts()               # count the ambiguous column names
# Out:
# 0
# Rank         24
# Rate         20
# State         1
# Rate_2023     1
# Rate_2022     1
# Rate_2021     1
# Rate_2020     1
# Name: count, dtype: int64

# %%
new_column_names = ['State']
years = list(range(2023,1999,-1))

for year in years:
    new_column_names.append(f"Rate_{year}")                 #Rename the column Rate_<YEAR>, Rank_<YEAR>
    new_column_names.append(f"Rank_{year}")

df_unemployed.columns = new_column_names
df_unemployed
# Out:
#                                  State Rate_2023 Rank_2023 Rate_2022  \
# 0                        United States       3.6       ---       3.6
# 1                              Alabama       2.5         7       2.5
# 2                               Alaska       4.2        44       4.2
# 3                              Arizona       3.9        38       3.8
# 4                             Arkansas       3.3        27       3.2
# 5                           California       4.8        49       4.3
# 6                             Colorado       3.2        23       3.1
# 7                          Connecticut       3.8        36       4.1
# 8                             Delaware         4        42       4.3
# 9                 District of Columbia       4.9        50       4.7
# 10                             Florida       2.9        11         3
# 11                             Georgia       3.2        23       3.1
# 12                              Hawaii         3        17       3.3
# ...

# %%
df_unemployed.columns.nunique()
# Out:
# 49

# %%
numeric_columns = df_unemployed.columns[1:]                 # change the datatype from object to float
df_unemployed[numeric_columns] = df_unemployed[numeric_columns].apply(pd.to_numeric, errors = 'coerce')
df_unemployed
# Out:
#                                  State  Rate_2023  Rank_2023  Rate_2022  \
# 0                        United States        3.6        NaN        3.6
# 1                              Alabama        2.5        7.0        2.5
# 2                               Alaska        4.2       44.0        4.2
# 3                              Arizona        3.9       38.0        3.8
# 4                             Arkansas        3.3       27.0        3.2
# 5                           California        4.8       49.0        4.3
# 6                             Colorado        3.2       23.0        3.1
# 7                          Connecticut        3.8       36.0        4.1
# 8                             Delaware        4.0       42.0        4.3
# 9                 District of Columbia        4.9       50.0        4.7
# 10                             Florida        2.9       11.0        3.0
# 11                             Georgia        3.2       23.0        3.1
# ...

# %%
df_unemployed = df_unemployed.fillna(0)             # fill the missing values with 0

# %%
df_unemployed.isnull().sum()
# Out:
# State        0
# Rate_2023    0
# Rank_2023    0
# Rate_2022    0
# Rank_2022    0
# Rate_2021    0
# Rank_2021    0
# Rate_2020    0
# Rank_2020    0
# Rate_2019    0
# Rank_2019    0
# Rate_2018    0
# Rank_2018    0
# Rate_2017    0
# Rank_2017    0
# Rate_2016    0
# Rank_2016    0
# Rate_2015    0
# Rank_2015    0
# Rate_2014    0
# Rank_2014    0
# Rate_2013    0
# Rank_2013    0
# Rate_2012    0
# Rank_2012    0
# Rate_2011    0
# Rank_2011    0
# Rate_2010    0
# Rank_2010    0
# Rate_2009    0
# Rank_2009    0
# Rate_2008    0
# Rank_2008    0
# Rate_2007    0
# Rank_2007    0
# Rate_2006    0
# Rank_2006    0
# Rate_2005    0
# Rank_2005    0
# Rate_2004    0
# Rank_2004    0
# Rate_2003    0
# Rank_2003    0
# Rate_2002    0
# Rank_2002    0
# Rate_2001    0
# Rank_2001    0
# Rate_2000    0
# Rank_2000    0
# dtype: int64

# %%
df_unemployed.drop([52],axis = 0)
# Out:
#                    State  Rate_2023  Rank_2023  Rate_2022  Rank_2022  \
# 0          United States        3.6        0.0        3.6        0.0
# 1                Alabama        2.5        7.0        2.5        7.0
# 2                 Alaska        4.2       44.0        4.2       45.0
# 3                Arizona        3.9       38.0        3.8       32.0
# 4               Arkansas        3.3       27.0        3.2       23.0
# 5             California        4.8       49.0        4.3       46.0
# 6               Colorado        3.2       23.0        3.1       19.0
# 7            Connecticut        3.8       36.0        4.1       40.0
# 8               Delaware        4.0       42.0        4.3       46.0
# 9   District of Columbia        4.9       50.0        4.7       50.0
# 10               Florida        2.9       11.0        3.0       17.0
# 11               Georgia        3.2       23.0        3.1       19.0
# 12                Hawaii        3.0       17.0        3.3       26.0
# ...

# %%
df_unemployed
# Out:
#                                  State  Rate_2023  Rank_2023  Rate_2022  \
# 0                        United States        3.6        0.0        3.6
# 1                              Alabama        2.5        7.0        2.5
# 2                               Alaska        4.2       44.0        4.2
# 3                              Arizona        3.9       38.0        3.8
# 4                             Arkansas        3.3       27.0        3.2
# 5                           California        4.8       49.0        4.3
# 6                             Colorado        3.2       23.0        3.1
# 7                          Connecticut        3.8       36.0        4.1
# 8                             Delaware        4.0       42.0        4.3
# 9                 District of Columbia        4.9       50.0        4.7
# 10                             Florida        2.9       11.0        3.0
# 11                             Georgia        3.2       23.0        3.1
# ...

# %%
df_unemployed.to_excel("cleaned_unemployed.xlsx",index = False) # fill

# %% [markdown]
# ## Data is cleaned Now
